# %%
import os
import json
from utils import read_json
from langchain.document_loaders import PyPDFLoader

from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
api_key = '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'

tokenizer = AutoTokenizer.from_pretrained("taide/Llama3-TAIDE-LX-8B-Chat-Alpha1", use_auth_token=api_key)
# Out:
# c:\Users\sean.chang\AppData\Local\anaconda3\envs\supervisor_llm\lib\site-packages\transformers\models\auto\tokenization_auto.py:757: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def get_whole_pdf(file_data):
    whole_pdf = ""
    for i in range(len(file_data)):
        whole_pdf += file_data[i].page_content

    return whole_pdf

# %%
configs = read_json('configs.json')
DATA_PATH = configs["DATA_PATH"]
DB_PATH = configs['DB_PATH']
files_list = [file for file in os.listdir(DATA_PATH) if os.path.isfile(os.path.join(DATA_PATH, file))]

def read_pdf(files_list, data_path=DATA_PATH):
    
    for file in files_list:
        loader = PyPDFLoader(data_path + file)
        content = loader.load()
        whole_pdf = ""
        for i in range(len(content)):
            whole_pdf += content[i].page_content

    return whole_pdf


pdf_content = read_pdf(files_list=[files_list[0]])

# %%
files_list
# Out:
# ['民政-108內正1.pdf',
#  '測量重劃-102內正17.pdf',
#  '都市計畫-102內正22.pdf',
#  '都市計畫-102內正30.pdf',
#  '都市計畫-107內正2.pdf']

# %%
pdf_108_1= read_pdf(files_list=[files_list[0]])
pdf_102_17= read_pdf(files_list=[files_list[1]])
pdf_102_22= read_pdf(files_list=[files_list[2]])
pdf_102_30= read_pdf(files_list=[files_list[3]])
pdf_107_2= read_pdf(files_list=[files_list[4]])

# %%
pdf_108_1
# Out:
# '1  \n糾正案文  \n壹、被糾正機關： 內政部。 \n貳、案   由：內政部制定殯葬管理條例時， 顯未能務實\n通盤瞭解殯葬業之問題，在法制上預為釐\n清因應，其後亦未能掌握問題之所在，致\n相關之規範及函釋未盡周延，歷時 10多年\n竟未能對症化解爭議，滋生諸多民怨，確\n有怠失，爰依法提案糾正 。 \n參、事實與理由：  \n本案經調閱 內政部等機關卷證資料，並於民國 (下\n同)107年4月9日、5月2日、5月4日、6月13日及6月22日\n抽選北部私立公墓、骨灰（骸）存放設施， 前往現場履\n勘，與業者及內政部、各該直轄市、縣 (市)政府等機關\n人員進行簡報與座談。嗣於 107年7月6日詢問案關會計\n師，及於107年8月8日詢問內政部陳宗彥政務次長及新北\n市政府林祐賢副祕書長暨業務相關主管人員 ，再於107\n年11月5日詢問內政部陳宗彥政務次長、金融監督管理委\n員會(下稱金管會 )張傳章政務副主任委員及新北市政府\n邱敬斌副祕書長暨業務相關主管人員。  \n本案調查發現， 殯葬管理條例於 91年公布迄今已 10\n多年，惟依據中華民國殯葬設施經營商業同業公會全國\n聯合會於內政部召開「研商私立公墓骨灰骸存放設施管\n理費專戶管理辦法修正草案及相關執行事宜」會議之意\n見要旨，目前經營殯葬設施業者約有 9成係殯葬管理條\n例施行前設立，同一殯葬設施多有切割經營之情形，因\n該條例施行後 1座設施僅有 1個經營業者，衍生諸多土地\n產權、經營及管理糾紛問題。又內政部雖召開上揭研商\n會議，惟各界意見尚有歧異，是以內政部制定該條例\n時，顯未能務實通盤瞭解殯葬業之問題，在法制上預為2  \n釐清因應，其後亦未能掌握問題之所在，致相關之規 範\n及函釋未盡周延，歷時 10多年竟未能對症化解爭議，滋\n生諸多民怨 ，確有怠失 ，應予糾正促其注意改善。茲臚\n列事實與理由如下 ： \n一、91年7月17日公布之殯葬管理條例第 32條規定： 「私立\n公墓、骨灰  (骸) 存放設施經營者應以收取之管理費\n設立專戶，專款專用。本條例施行前已設置之私立公\n墓、骨灰  (骸) 存放設施，亦同。前項管理費專戶管\n理辦法，由中央主管機關定之。」第 37條規定： 「殯\n葬服務業分殯葬設施經營業及殯葬禮儀服務業。」及\n第38條規定： 「 (第1項) 經營殯
# ...

# %%
pdf_102_22
# Out:
# ' 1 糾正案文  \n壹、被糾正機關： 內政部及各級地方政府 。 \n貳、案   由：各級都市計畫 權責機關任令 部分都市計畫\n公共設施保留地 長達3、40年迄未取得，\n嚴重傷害憲法保障人民之生存權與財產權\n，內政部及各級地方政府實有嚴重怠失 ，\n爰依法提案糾正。  \n參、事實與理由：  \n全國各市縣都市計畫劃定之公共設施保留地，經劃\n定後歷數十年迄未徵收使用之個案甚多，致積累民怨已\n深，事涉憲法保障之人民生存權與財產權，究實情如何\n？認有深入瞭解之必要乙案 ，經本院調查竣事，發現 內\n政部及各級地方政府 均核有嚴重怠失。茲說明如下：  \n一、都市計畫法 第5條、第15條第2項規定：「 都市\n計畫應依據現在及既往情況，並預計二十五年內之發\n展情形訂定之 。」、「前項主要計畫書， …；其實施\n進度以五年為一期，最長不得超過二十五年。 」同法\n第26條規定：「都市計畫經發布實施後，不得隨時任\n意變更。但擬定計畫之機關每三年內或五年內至少應\n通盤檢討一次，依據發展情況，並參考人民建議作必\n要之變更。對於非必要之公共設施用地，應變更其使\n用。」表示都市計畫前瞻 25年，應有其意義 ，都\n市計畫編定公共設施用地， 最長應於 25年內完成 ，\n逾25年仍未取得開發之 公共設施 用地，理應限期檢\n討，對不必要的部分應儘速解編 ，如逾3、40年仍不\n取得使用，更表示已無 公共設施用地保留 之必要。 \n二、憲法第15條規定： 「 人民之生存權、工作權及財產權，\n應予保障 。」經劃設為公共設施保留地者，雖得為原\n來之使用或改為妨礙目的較輕之使用，但不得為妨礙 2 其指定目的之使用，土地所有權人之使用收益不但遭\n受限制，復因無法撤銷使用管制，土地價值深受重大\n影響。 \n三、根據內政部統計資料，截至 100年，都市計畫公共設\n施保留地未徵收面積達 25,714公頃，預估徵購所需費\n用約新臺幣 7兆餘元。內政部提供之 100年底各縣市\n未徵收都市計畫公共設施用地面積及項目如 表1、2。\n其中，未徵收都市計畫公共設施 用地以新北市最多，\n面積達6,328.69 公頃，占 24.61％，其次為臺中市，\n面積達2,965.55 公頃，占 11.53％，第三為臺南市，\n面積達2,460.44 公頃，占 9.57％。未徵收都
# ...

# %%
def tokenization_reshpae(input_data):
    return np.array(tokenizer(input_data, max_length=5000, truncation=True)['input_ids']).reshape(1, -1)

# %%
encoded_pdf_108_1 = tokenization_reshpae(pdf_108_1)
encoded_pdf_102_17 = tokenization_reshpae(pdf_102_17)
encoded_pdf_102_22 = tokenization_reshpae(pdf_102_22)
encoded_pdf_102_30 = tokenization_reshpae(pdf_102_30)
encoded_pdf_107_2 = tokenization_reshpae(pdf_107_2)

# %%
simlarity_1 = cosine_similarity(encoded_pdf_102_30, encoded_pdf_107_2)[0]
simlarity
# Out:
# array([0.63672016])

# %%
vectors = {
    'encoded_pdf_108_1': encoded_pdf_108_1,
    'encoded_pdf_102_17': encoded_pdf_102_17,
    'encoded_pdf_102_30': encoded_pdf_102_30,
    'encoded_pdf_107_2': encoded_pdf_107_2
}

# Create an empty DataFrame
similarity_df = pd.DataFrame(index=vectors.keys(), columns=vectors.keys())

# Calculate cosine similarity between each pair of vectors
for name1, vec1 in vectors.items():
    for name2, vec2 in vectors.items():
        similarity_df.loc[name1, name2] = cosine_similarity(vec1, vec2)[0][0]

# %%
similarity_df
# Out:
#                    encoded_pdf_108_1 encoded_pdf_102_17 encoded_pdf_102_30  \
# encoded_pdf_108_1                1.0           0.650832           0.633832
# encoded_pdf_102_17          0.650832                1.0           0.654246
# encoded_pdf_102_30          0.633832           0.654246                1.0
# encoded_pdf_107_2           0.619413           0.640591            0.63672
#
#                    encoded_pdf_107_2
# encoded_pdf_108_1           0.619413
# encoded_pdf_102_17          0.640591
# encoded_pdf_102_30           0.63672
# encoded_pdf_107_2                1.0
